# %%
import requests
from datetime import datetime
from pathlib import Path
import pandas as pd

BASE_FILE_DIR = Path('/tmp')
file_path_crib = '{category}/{year}-{month: 02d}/{category}-{day: 02d}-{month:02d}-{year}.csv'

# %%
categories=[
    {
        
    
    'name': 'museo',
    'url': 'https://datos.cultura.gob.ar/dataset/37305de4-3cce-4d4b-9d9a-fec3ca61d09f/resource/4207def0-2ff7-41d5-9095-d42ae8207a5d/download/museos_datosabiertos.csv'
    
    }, 
    
    {
    'name': 'cines',
    'url': 'https://datos.cultura.gob.ar/dataset/37305de4-3cce-4d4b-9d9a-fec3ca61d09f/resource/f7a8edb8-9208-41b0-8f19-d72811dcea97/download/salas_cine.csv '
    },
    
    {
    'name': 'bibliotecas_populares',
    'url': 'https://datos.cultura.gob.ar/dataset/37305de4-3cce-4d4b-9d9a-fec3ca61d09f/resource/01c6c048-dbeb-44e0-8efa-6944f73715d7/download/11_bibliotecapopular-datos-abiertos.csv ' 
    }
    
]

# %% [markdown]
# ## Museos

# %% [markdown]
# ### Extract

# %%
category_dict = categories[0]
r = requests.get(category_dict['url'])
r.encoding='utf-8'

# %%
now = datetime.now()

file_path = file_path_crib.format(category=category_dict['name'], year=now. year, month=now.month, day=now.day)

m_path = BASE_FILE_DIR/file_path
m_path.parent.mkdir (parents=True, exist_ok=True)

## Save file
with open (m_path, 'w',encoding= 'utf-8') as f_out:
    f_out.write(r.text)

# %% [markdown]
# ### Transform

# %%
df = pd.read_csv(m_path,encoding='utf-8')

# %%
df.head()
# Out:
#    Cod_Loc  IdProvincia  IdDepartamento  Observaciones  \
# 0  6588100            6            6588            NaN
# 1  6077010            6            6077            NaN
# 2  6035010            6            6035            NaN
# 3  6035010            6            6035            NaN
# 4  6049020            6            6049            NaN
#
#                             categoria subcategoria     provincia   localidad  \
# 0  Espacios de Exhibición Patrimonial       Museos  Buenos Aires  9 de Julio
# 1  Espacios de Exhibición Patrimonial       Museos  Buenos Aires   Arrecifes
# 2  Espacios de Exhibición Patrimonial       Museos  Buenos Aires  Avellaneda
# 3  Espacios de Exhibición Patrimonial       Museos  Buenos Aires  Avellaneda
# 4  Espacios de Exhibición Patrimonial       Museos  Buenos Aires        Azul
#
#                                               nombre  \
# 0     Archivo Y Museo Histórico Gral. Julio De Vedia
# 1             Museo Y Archivo Histórico De Arrecifes
# 2    Museo Histórico-Sacro  Hno. Rogelio Scortegagna
# 3   Museo Municipal De Artes Plásticas De Avellaneda
# 4  Museo Etnográfico Y Archivo Histórico Enrique ...
#
#                           direccion  ...                        Mail  \
# 0                     Libertad 1191  ...  archivoymuseo@yahoo.com.ar
# 1            Gerardo Risso y España  ...  museoarrecifes@hotmail.com
# 2  Calle 11 (Av. San Martín) Nº 830  ...                         NaN
# 3           Sarmiento 101, 1 º Piso  ...                         NaN
# 4            Bartolomé J. Ronco 654  ...         museoazul@yahoo.com
#
#                      Web    Latitud   Longitud   TipoLatitudLongitud  \
# 0  www.portaldel9.com.ar -35.441762 -60.887598  Localización precisa
# 1                    NaN -34.066970 -60.102555  Localización precisa
# 2                    NaN -29.118024 -59.654543  Localización precisa
# 3                    NaN -34.662110 -58.363270  Localización precisa
# 4                    NaN -36.781824 -59.858636  Localización precisa
#
#   Info_adicional  fuente  jurisdiccion año_inauguracion actualizacion
# 0            NaN   DNPyM     Municipal           1920.0          2017
# 1            NaN   DNPyM     Municipal           1972.0          2017
# 2            NaN   DNPyM     Municipal              NaN          2017
# 3            NaN   DNPyM     Municipal           1956.0          2017
# 4            NaN   DNPyM       Privada           1949.0          2017
#
# [5 rows x 24 columns]

# %%
renamed_cols = {
    'Cod_Loc': 'cod_localidad', 
    'IdProvincia': 'id_provincia',
    'IdDepartamento': 'id_departamento', 
    'direccion': 'domicilio',
    'CP': 'codigo postal',
    'telefono': 'número de teléfono',
    'Mail': 'mail',
    'Web': 'web',
}

# %%
df = df.rename(columns = renamed_cols)

colum_list = [
    'cod_localidad',
    'id_provincia',
    'id_departamento',
    'categoria',
    'provincia',
    'localidad',
    'nombre',
    'domicilio',
    'codigo postal',
    'número de teléfono',
    'mail',
    'web',
]   
df_museos= df[colum_list]

# %%
df_museos
# Out:
#       cod_localidad  id_provincia  id_departamento  \
# 0           6588100             6             6588
# 1           6077010             6             6077
# 2           6035010             6             6035
# 3           6035010             6             6035
# 4           6049020             6             6049
# ...             ...           ...              ...
# 1177       90098040            90            90098
# 1178       90105080            90            90105
# 1179       90105080            90            90105
# 1180       90105070            90            90105
# 1181       90098040            90            90098
#
#                                categoria     provincia          localidad  \
# 0     Espacios de Exhibición Patrimonial  Buenos Aires         9 de Julio
# 1     Espacios de Exhibición Patrimonial  Buenos Aires          Arrecifes
# 2     Espacios de Exhibición Patrimonial  Buenos Aires         Avellaneda
# 3     Espacios de Exhibición Patrimonial  Buenos Aires         Avellaneda
# 4     Espacios de Exhibición Patrimonial  Buenos Aires               Azul
# ...                                  ...           ...                ...
# 1177  Espacios de Exhibición Patrimonial       Tucumán     Tafí del Valle
# 1178  Espacios de Exhibición Patrimonial       Tucumán         Tafí Viejo
# 1179  Espacios de Exhibición Patrimonial       Tucumán         Tafí Viejo
# 1180  Espacios de Exhibición Patrimonial       Tucumán  Villa El Cadillal
# 1181  Espacios de Exhibición Patrimonial       Tucumán     Tafí del Valle
#
#                                                  nombre  \
# 0        Archivo Y Museo Histórico Gral. Julio De Vedia
# 1                Museo Y Archivo Histórico De Arrecifes
# 2       Museo Histórico-Sacro  Hno. Rogelio Scortegagna
# 3      Museo Municipal De Artes Plásticas De Avellaneda
# 4     Museo Etnográfico Y Archivo Histórico Enrique ...
# ...                                                 ...
# 1177  Museo Histórico Y Arqueológico Jesuítico La Banda
# 1178                 Mac-Museo Arqueológico El Cadillal
# 1179    Museo Ferroviario De Los Talleres De Tafí Viejo
# 1180             Museo Arqueológico Dr. Ernesto Padilla
# 1181  Asentamientos De Menhires En Las Áreas Arqueol...
#
#                              domicilio codigo postal número de teléfono  \
# 0                        Libertad 1191      B6500EVL            425 279
# 1               Gerardo Risso y España      B2740FMJ            452 931
# 2     Calle 11 (Av. San Martín) Nº 830      S3561AKT            481 200
# 3              Sarmiento 101, 1 º Piso      B1870CBC          4205 9567
# 4               Bartolomé J. Ronco 654      B7300XAA            434 811
# ...                                ...           ...                ...
# 1177                      La Banda S/N          4000            421 685
# 1178      Centro Principal el Cadillal           NaN                NaN
# 1179   Avda. Pte. Roque Sáenz Peña 234          4103           461 4335
# 1180               Ernesto Padilla S/N          4101           422 2199
# 1181                               NaN           NaN                NaN
#
#                             mail                             web
# 0     archivoymuseo@yahoo.com.ar           www.portaldel9.com.ar
# 1     museoarrecifes@hotmail.com                             NaN
# 2                            NaN                             NaN
# 3                            NaN                             NaN
# 4            museoazul@yahoo.com                             NaN
# ...                          ...                             ...
# 1177                         NaN                             NaN
# 1178                         NaN                             NaN
# 1179                         NaN                             NaN
# 1180                         NaN                             NaN
# 1181                         NaN  www.enteculturaltucuman.gov.ar
#
# [1182 rows x 12 columns]

# %% [markdown]
# ## Cines

# %% [markdown]
# ### Extract

# %%
category_dict = categories[1]
r = requests.get(category_dict['url'])
r.encoding='utf-8'

now = datetime.now()

file_path = file_path_crib.format(category=category_dict['name'], year=now. year, month=now.month, day=now.day)

m_path = BASE_FILE_DIR/file_path
m_path.parent.mkdir (parents=True, exist_ok=True)

## Save file
with open (m_path, 'w',encoding= 'utf-8') as f_out:
    f_out.write(r.text)

# %% [markdown]
# ## Transform

# %%
df = pd.read_csv(m_path,encoding='utf-8')
df.head(5)
# Out:
#    cod_localidad  id_provincia  id_departamento      categoria     provincia  \
# 0        6854100             6             6854  Salas de cine  Buenos Aires
# 1        6826040             6             6826  Salas de cine  Buenos Aires
# 2        6588100             6             6588  Salas de cine  Buenos Aires
# 3        6028010             6             6028  Salas de cine  Buenos Aires
# 4        6028010             6             6028  Salas de cine  Buenos Aires
#
#       departamento     localidad                   nombre  \
# 0       25 de mayo    25 de mayo      Cine Teatro Español
# 1  Trenque Lauquen  30 de agosto  Cine Santa Rosa De Lima
# 2       9 de julio    9 de julio       Tu Cine 9 de Julio
# 3  Almirante Brown       Adrogué           Cinema Adrogue
# 4  Almirante Brown       Adrogué        CPM Paseo Adrogue
#
#                  direccion piso  ...    latitud   longitud  \
# 0    Calle 9 entre 29 Y 30  NaN  ... -35.430488 -60.170686
# 1   Santa Rosa De Lima 170  NaN  ... -36.278508 -62.544355
# 2               Robbio 840  NaN  ... -35.446265 -60.885789
# 3  Hipolito Yrigoyen 13200  NaN  ... -34.808110 -58.402400
# 4                Segui 699  NaN  ... -34.800097 -58.396753
#
#    tipo_latitud_longitud         fuente sector pantallas butacas  \
# 0                Precisa  INCAA / SInCA   Cine         1     500
# 1                Precisa  INCAA / SInCA   Cine         1     410
# 2                Precisa  INCAA / SInCA   Cine         1     165
# 3                Precisa  INCAA / SInCA   Cine        10    2505
# 4                Precisa  INCAA / SInCA   Cine         4     710
#
#    tipo_de_gestion  espacio_incaa año_actualizacion
# 0          Pública             No              2022
# 1          Pública             No              2022
# 2          Privada             No              2022
# 3          Privada             No              2022
# 4          Privada             No              2022
#
# [5 rows x 22 columns]

# %%
df.groupby('provincia', as_index=False).count()[['provincia', 'pantallas', 'butacas', 'espacio_incaa']]
# Out:
#                           provincia  pantallas  butacas  espacio_incaa
# 0                      Buenos Aires        101      101            101
# 1                         Catamarca          2        2              2
# 2                             Chaco          3        3              3
# 3                            Chubut          8        8              8
# 4   Ciudad Autónoma de Buenos Aires         37       37             37
# 5                        Corrientes          7        7              7
# 6                           Córdoba         36       36             36
# 7                        Entre Ríos         11       11             11
# 8                           Formosa          1        1              1
# 9                             Jujuy          4        4              4
# 10                         La Pampa          5        5              5
# 11                         La Rioja          6        6              6
# 12                          Mendoza         17       17             17
# 13                         Misiones          4        4              4
# 14                          Neuquén          7        7              7
# 15                        Río Negro          6        6              6
# 16                            Salta          7        7              7
# 17                         San Juan          4        4              4
# 18                         San Luis          3        3              3
# 19                       Santa Cruz          8        8              8
# 20                         Santa Fe         21       21             21
# 21              Santiago del Estero          4        4              4
# 22                 Tierra del Fuego          3        3              3
# 23                          Tucumán         11       11             11

# %%
df.dtypes
# Out:
# cod_localidad              int64
# id_provincia               int64
# id_departamento            int64
# categoria                 object
# provincia                 object
# departamento              object
# localidad                 object
# nombre                    object
# direccion                 object
# piso                      object
# cp                         int64
# web                       object
# latitud                  float64
# longitud                 float64
# tipo_latitud_longitud     object
# fuente                    object
# sector                    object
# pantallas                  int64
# butacas                    int64
# tipo_de_gestion           object
# espacio_incaa             object
# año_actualizacion          int64
# dtype: object

# %%
renamed_cols = {
    'Cod_Loc': 'cod_localidad',
    'IdProvincia':
    'id_provincia',
    'IdDepartamento': 'id_departamento',
    'Provincia': 'provincia',
    'Categoría': 'categoria',
    'Dirección': 'domicilio', 
    'CP': 'codigo postal',
    'Localidad': 'localidad',
    'Nombre': 'nombre',
    'Domicilio': 'domicilio',
    'Teléfono': 'número de teléfono',
    'Mail': 'mail',
    'Web': 'web',
    }

df= df.rename(columns = renamed_cols)

# %%
colum_list = [
    'cod_localidad',
    'id_provincia',
    'id_departamento',
    'categoria',
    'provincia',
    'localidad',
    'nombre',
    'web',
]   
df_cines= df[colum_list]

# %%
df_cines
# Out:
#      cod_localidad  id_provincia  id_departamento      categoria  \
# 0          6854100             6             6854  Salas de cine
# 1          6826040             6             6826  Salas de cine
# 2          6588100             6             6588  Salas de cine
# 3          6028010             6             6028  Salas de cine
# 4          6028010             6             6028  Salas de cine
# ..             ...           ...              ...            ...
# 311       90084010            90            90084  Salas de cine
# 312       90084010            90            90084  Salas de cine
# 313       90084010            90            90084  Salas de cine
# 314       90119030            90            90119  Salas de cine
# 315       90119030            90            90119  Salas de cine
#
#         provincia              localidad                               nombre  \
# 0    Buenos Aires             25 de mayo                  Cine Teatro Español
# 1    Buenos Aires           30 de agosto              Cine Santa Rosa De Lima
# 2    Buenos Aires             9 de julio                   Tu Cine 9 de Julio
# 3    Buenos Aires                Adrogué                       Cinema Adrogue
# 4    Buenos Aires                Adrogué                    CPM Paseo Adrogue
# ..            ...                    ...                                  ...
# 311       Tucumán  San Miguel de Tucumán                 Cinemacenter Tucuman
# 312       Tucumán  San Miguel de Tucumán  Espacio Incaa Sala Orestes Caviglia
# 313       Tucumán  San Miguel de Tucumán                      Microcine Orion
# 314       Tucumán            Yerba Buena                      Solar del Cerro
# 315       Tucumán            Yerba Buena                      Sunstar Tucuman
#
#                                            web
# 0    https://www.instagram.com/teatro_espanol/
# 1            https://www.trenquelauquen.gov.ar
# 2               http://9dejulio.tucine.com.ar/
# 3               https://www.cinemaadrogue.com/
# 4                        https://cpmcines.com/
# ..                                         ...
# 311            http://www.cinemacenter.com.ar/
# 312        https://enteculturaltucuman.gob.ar/
# 313                                        NaN
# 314                   http://solardelcerro.com
# 315                http://www.cinesunstar.com/
#
# [316 rows x 8 columns]

# %% [markdown]
# ## Bibliotecas

# %%
category_dict = categories[2]
r = requests.get(category_dict['url'])
r.encoding='utf-8'

now = datetime.now()

file_path = file_path_crib.format(category=category_dict['name'], year=now. year, month=now.month, day=now.day)

m_path = BASE_FILE_DIR/file_path
m_path.parent.mkdir (parents=True, exist_ok=True)

## Save file
print(categories[2]['name'])
with open (m_path, 'w',encoding= 'utf-8') as f_out:
    f_out.write(r.text)
# Out:
# bibliotecas_populares

# %%
df = pd.read_csv(m_path,encoding='utf-8')
df.head(5)
# Out:
#    cod_localidad  id_provincia  id_departamento  observacion  \
# 0        6854100             6             6854          NaN
# 1        6588100             6             6588          NaN
# 2        6588100             6             6588          NaN
# 3        6007010             6             6007          NaN
# 4        6007080             6             6007          NaN
#
#             categoria  subcategoria     provincia   departamento   localidad  \
# 0  Biblioteca Popular           NaN  Buenos Aires     25 De Mayo  25 de Mayo
# 1  Biblioteca Popular           NaN  Buenos Aires     9 De Julio  9 de Julio
# 2  Biblioteca Popular           NaN  Buenos Aires     9 De Julio  9 de Julio
# 3  Biblioteca Popular           NaN  Buenos Aires  Adolfo Alsina      Carhue
# 4  Biblioteca Popular           NaN  Buenos Aires  Adolfo Alsina      Rivera
#
#                                               nombre  ...  \
# 0  Comité Cultural y Biblioteca Juan Francisco Ib...  ...
# 1                          Bib.Pop. Anastasio Prieto  ...
# 2                           Bib.Pop. José Ingenieros  ...
# 3                             Bib.Pop. Adolfo Alsina  ...
# 4                           Bib.Pop. José Ingenieros  ...
#
#                     mail  web informacion_adicional    latitud   longitud  \
# 0                    NaN  NaN                   NaN -35.432917 -60.171417
# 1                    NaN  NaN                   NaN -35.433333 -60.866667
# 2                    NaN  NaN                   NaN -35.445957 -60.883377
# 3                    NaN  NaN                   NaN -37.180933 -62.760050
# 4  ccibiblio@hotmail.com  NaN                   NaN -37.162600 -63.247050
#
#   tipo_latitud_longitud   fuente  fecha_fundacion  nro_conabip  \
# 0                Exacta  CONABIP       1922-10-02          938
# 1                Exacta  CONABIP       1980-01-01          200
# 2                Exacta  CONABIP       1933-10-12         1850
# 3                Exacta  CONABIP       1912-08-23           88
# 4                Exacta  CONABIP       1925-01-01         1278
#
#    anio_actualizacion
# 0                2023
# 1                2023
# 2                2023
# 3                2023
# 4                2023
#
# [5 rows x 25 columns]

# %%
renamed_cols = {
        'Cod_Loc': 'cod_localidad', 
        'IdProvincia': 'id_provincia',
        'IdDepartamento': 'id_departamento', 
        'Dirección': 'domicilio',
        'CP': 'codigo postal',
        'Localidad':'localidad',
        'Nombre':'nombre',
        'Domicilio': "domicilio",
        'Teléfono': 'número de teléfono',
        'Mail': 'mail',
        'Web': 'web',
    }

df = df.rename(columns = renamed_cols)

colum_list = [
    'cod_localidad',
    'id_provincia',
    'id_departamento',
    'categoria',
    'provincia',
    'localidad',
    'nombre',
    'web',
]   
df_bibliotecas= df[colum_list]

# %%
df_bibliotecas
# Out:
#       cod_localidad  id_provincia  id_departamento           categoria  \
# 0           6854100             6             6854  Biblioteca Popular
# 1           6588100             6             6588  Biblioteca Popular
# 2           6588100             6             6588  Biblioteca Popular
# 3           6007010             6             6007  Biblioteca Popular
# 4           6007080             6             6007  Biblioteca Popular
# ...             ...           ...              ...                 ...
# 1897       90105080            90            90105  Biblioteca Popular
# 1898       90105080            90            90105  Biblioteca Popular
# 1899       90105080            90            90105  Biblioteca Popular
# 1900       90105100            90            90105  Biblioteca Popular
# 1901       90119030            90            90119  Biblioteca Popular
#
#          provincia                   localidad  \
# 0     Buenos Aires                  25 de Mayo
# 1     Buenos Aires                  9 de Julio
# 2     Buenos Aires                  9 de Julio
# 3     Buenos Aires                      Carhue
# 4     Buenos Aires                      Rivera
# ...            ...                         ...
# 1897       Tucumán                  Tafi Viejo
# 1898       Tucumán                  Tafi Viejo
# 1899       Tucumán                  Tafi Viejo
# 1900       Tucumán  Villa M.Moreno-Las Talitas
# 1901       Tucumán                 Yerba Buena
#
#                                                  nombre  web
# 0     Comité Cultural y Biblioteca Juan Francisco Ib...  NaN
# 1                             Bib.Pop. Anastasio Prieto  NaN
# 2                              Bib.Pop. José Ingenieros  NaN
# 3                                Bib.Pop. Adolfo Alsina  NaN
# 4                              Bib.Pop. José Ingenieros  NaN
# ...                                                 ...  ...
# 1897                          Bib.Pop. Ing. A. Pasquini  NaN
# 1898                     Bib.Pop. Juan Bautista Alberdi  NaN
# 1899                         Bib.Pop. Hipólito Yrigoyen  NaN
# 1900                      Bib.Pop. Manuel Lizondo Borda  NaN
# 1901                                  Bib.Pop. La Randa  NaN
#
# [1902 rows x 8 columns]

# %%
df_bibliotecas['id_departamento'].isna().unique()
# Out:
# array([False])

# %% [markdown]
# ### Now, Let's generate a dict with all the dfs in order to analyze all the data together

# %%
dfs = {'museos': df_museos, 'cines': df_cines, 'bibliotecas': df_bibliotecas}

# %%
dfss = pd.concat(dfs, axis=0)

# %%
dfss.dtypes
# Out:
# cod_localidad          int64
# id_provincia           int64
# id_departamento        int64
# categoria             object
# provincia             object
# localidad             object
# nombre                object
# domicilio             object
# codigo postal         object
# número de teléfono    object
# mail                  object
# web                   object
# dtype: object

# %%
# Count by category
dfss.groupby('categoria', as_index=False).size()
# Out:
#                             categoria  size
# 0                  Biblioteca Popular  1902
# 1  Espacios de Exhibición Patrimonial  1182
# 2                       Salas de cine   316

# %%
# Count by category and province
dfss.groupby(['categoria', 'provincia'], as_index=False).size()
# Out:
#              categoria                        provincia  size
# 0   Biblioteca Popular                     Buenos Aires   497
# 1   Biblioteca Popular                        Catamarca    37
# 2   Biblioteca Popular                            Chaco    69
# 3   Biblioteca Popular                           Chubut    47
# 4   Biblioteca Popular  Ciudad Autónoma de Buenos Aires    43
# ..                 ...                              ...   ...
# 67       Salas de cine                       Santa Cruz     8
# 68       Salas de cine                         Santa Fe    21
# 69       Salas de cine              Santiago del Estero     4
# 70       Salas de cine                 Tierra del Fuego     3
# 71       Salas de cine                          Tucumán    11
#
# [72 rows x 3 columns]

# %%
# Count by source list

lst= list()

for name, df in dfs.items():
    lst.append({'source': name, 'count': df.size,})

pd.DataFrame(lst)
# Out:
#         source  count
# 0       museos  14184
# 1        cines   2528
# 2  bibliotecas  15216
